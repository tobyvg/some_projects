# %% [markdown]
# # How to use project scripts

# %%
from project_utilities import *
from project_utilities import visualize_matrix as vis_mat
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
init_mpl(130) # initialize matplotlib at prefered settings

# %% [markdown]
# ## Mol object
#
# ### Loading in .xyz file

# %%
mol = Mol() 
mol.read_xyz('xyz_files/water.xyz')
mol.vis_mol()
mol.print_geometry()
# Out:
# (0), H: [0.7763 0.512  0.    ]
# (1), H: [-0.7763  0.512   0.    ]
# (2), O: [ 0.     -0.0645 -0.    ]

# %% [markdown]
# ## Custom molecule

# %%
mol = Mol(atom_numbers = [1,9],coords = [[0,0,0],[1,0,0]]) ## HF molecule
mol.vis_mol()
mol.print_geometry()
# Out:
# (0), H: [0 0 0]
# (1), F: [1 0 0]

# %% [markdown]
# ## Save structure

# %%
string = mol.xyz_string()
f = open('HF.xyz','w')
f.write(string)
f.close()
######################### OR ######################
mol.output_xyz(name = 'HF',folder = 'geometries')
# Out:
# Geometry saved as: geometries/HF_5.xyz

# %% [markdown]
# ## Rotate molecule in space

# %%
mol = Mol()
mol.read_xyz('xyz_files/paracetamol.xyz')
mol.vis_mol(plot = False)
plt.title('Original .xyz file')
plt.show()
mol.print_geometry()
mol.rand_rotation() ### provide a random rotation, or use mol.rotation(x_rot,y_rot,z_rot) and provide rotation in radians
                    ### along each of the axes.
mol.vis_mol(plot = False)
plt.title('Randomly rotated molecule')
plt.show()
mol.print_geometry()
# Out:
# (0), H: [-4.1536  1.23   -0.0378]
# (1), H: [-4.2813 -0.1968 -1.0943]
# (2), H: [-1.8716  1.6564 -0.5825]
# (3), H: [ 3.9624 -0.6904  0.9958]
# (4), H: [ 1.8871 -2.1386 -0.4977]
# (5), H: [-0.5084 -1.5961 -0.6498]
# (6), H: [2.7499 1.9337 0.4684]
# (7), H: [0.3553 2.4792 0.3125]
# (8), H: [-4.5613 -0.3577  0.6561]
# (9), C: [-3.9789  0.1564 -0.1085]
# (10), C: [0.6912 1.4676 0.1387]
# (11), C: [ 1.5499 -1.1281 -0.3196]
# (12), C: [ 2.4673 -0.1363 -0.005 ]
# (13), C: [ 0.2057 -0.8238 -0.4052]
# (14), C: [2.0351 1.1619 0.2239]
# (15), C: [-0.2276  0.4753 -0.1762]
# (16), C: [-2.5138 -0.1288  0.0996]
# (17), N: [-1.5914  0.7847 -0.2624]
# (18), O: [ 3.7908 -0.4365  0.0786]
# (19), O: [-2.1648 -1.1805  0.5929]
# (0), H: [ 0.09569134 -3.34137786 -2.75549614]
# (1), H: [-0.90498775 -2.22462478 -3.71453822]
# (2), H: [-0.55925447 -2.41681512 -0.65733771]
# (3), H: [0.85049342 2.7825006  2.95012456]
# (4), H: [-0.50348885  2.83047315  0.34261114]
# (5), H: [-0.57269315  1.04239895 -1.3467267 ]
# (6), H: [ 0.28526206 -0.06857747  3.38148887]
# (7), H: [ 0.21212262 -1.85861802  1.69436419]
# (8), H: [ 0.86016486 -2.25607683 -3.94133327]
# (9), C: [ 0.05447649 -2.35317623 -3.21363849]
# (10), C: [ 0.05902404 -0.83123058  1.39871969]
# (11), C: [-0.34600402  1.80325063  0.63679837]
# (12), C: [-0.10460768  1.49214161  1.96691195]
# (13), C: [-0.38508396  0.79999616 -0.31122733]
# (14), C: [0.0977652  0.17301898 2.34569419]
# (15), C: [-0.18259556 -0.52048806  0.06715152]
# (16), C: [ 0.21011105 -1.29876728 -2.14819854]
# (17), N: [-0.22162084 -1.53892395 -0.8942925 ]
# (18), O: [-0.06679028  2.48043568  2.89997461]
# (19), O: [ 0.72394425 -0.23399403 -2.41921913]

# %% [markdown]
# ## PySCF (https://sunqm.github.io/pyscf/)
# ### Doing a DFT calculation

# %%
from pyscf import gto, scf, cc, fci, dft

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/ethanol.xyz')

mol1 = gto.M(atom=mol.pyscf_out(), basis=basis) ### Link Mol object to PySCF
mf = dft.rks.RKS(mol1) 
mf.xc = functional
mf.kernel()
# Out:
# converged SCF energy = -154.308127777613
# -154.30812777761344

# %% [markdown]
# ## Important features

# %%
# Pre-calculation
e = mol1.nelec[0] # Number of electrons/2 for closed-shell systems
S =  mol1.intor('int1e_ovlp_sph') # Overlap mattrix



# Post-calculation
E = mf.energy_tot() # Total energy
F = mf.get_fock() # Fock matrix
C = mf.mo_coeff # Coefficient matrix
MOs = mf.mo_energy # MO energies

# %% [markdown]
# ## Potential energy surface

# %%
mol = Mol()
mol.read_xyz('xyz_files/ethanol.xyz')
mol.print_geometry()
# Out:
# (0), H: [-0.49334  0.93505  1.44716]
# (1), H: [1.05522 0.04512 1.44808]
# (2), H: [-0.64695 -1.12346  2.54219]
# (3), H: [ 0.50112 -0.9164  -0.8044 ]
# (4), H: [ 0.49999  0.86726 -0.84481]
# (5), H: [-1.0431  -0.02739 -0.80544]
# (6), C: [0.01247 0.02254 1.08262]
# (7), C: [-0.00894 -0.01624 -0.43421]
# (8), O: [-0.66442 -1.15471  1.56909]

# %%
basis = 'sto-6g'
functional = 'pbe'
rotations = np.linspace(0,2*np.pi,20)
energies = []
for i in rotations:
    mol = Mol()
    mol.read_xyz('xyz_files/ethanol.xyz')
    mol.rotate_plane(index1 = 6, index2 = 7,angle = i) # Rotate one side of the plane separating atom 6 and 7
                                                    #that is orthogonal to the bond
    mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
    mf = dft.rks.RKS(mol1) 
    mf.xc = functional
    mf.kernel()
    E = mf.energy_tot()
    energies.append(E)
clear_output()
plt.plot(rotations,energies,marker = 'o')
plt.xlabel('$\phi$ (rad)')
plt.ylabel('$E$')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluating density and MOs
#
# Note that the $x$ and $y$ axis are interchanged with respect to the .xyz file
#
# https://sunqm.github.io/pyscf/_modules/pyscf/tools/cubegen.html#density Finding density
#
# https://sunqm.github.io/pyscf/_modules/pyscf/dft/numint.html Finding orbitals

# %%
######## DFT calculation
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/water.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional
mf.kernel()
clear_output()
############## Evaluate MO ###############
res = 50 # sampling resolution, real resolution = res^3
C = mf.mo_coeff
## samples the lowest energy MO (orbital = 0), samples in MOcube and coordinates in steps (Bohr)
MOcube, steps = MO(mol1,C,orbital = 0,outfile = 'orbital', nx=res, ny=res, nz=res, save = True) 
print(steps)
vis_mat(MOcube[:,:,15],ranges = [steps[0,0],steps[0,1],steps[1,0],steps[1,1]],x_points = 7,y_points = 7,plot = False)
plt.title('MO')
plt.xlabel('$x$ (Bohr)')
plt.ylabel('$y$ (Bohr)')
plt.show()
# Out:
# [[-3.12188734  3.96753978 50.        ]
#  [-4.46699439  4.46699439 50.        ]
#  [-3.          3.         50.        ]]

# %%
######## DFT calculation
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/water.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional
mf.kernel()
clear_output()
############## Evaluate MO ###############
res = 50 # sampling resolution, real resolution = res^3
C = mf.mo_coeff
e = mol1.nelec[0] 
dm = 2*C[:,:e] @ C.T[:e,:] # Density matrix multiplied by 2 for doubly-occupied MOs in closed-shell systems
## samples the lowest energy MO (orbital = 0), samples in MOcube and coordinates in steps (Bohr)
densitycube, steps = density(mol1, dm, outfile = 'rho', nx=res, ny=res, nz=res, save = True)
vis_mat(densitycube[:,:,15],ranges = [steps[0,0],steps[0,1],steps[1,0],steps[1,1]],x_points = 7,y_points = 7,plot = False)
plt.title('$ρ$')
plt.xlabel('$x$ (Bohr)')
plt.ylabel('$y$ (Bohr)')
plt.show()

# %% [markdown]
# ### Can be reloaded form saved data

# %%
MOcube,steps = read_cube('orbital')
densitycube,steps = read_cube('rho')

# %% [markdown]
# ## Matrices
#
# Matrix elements are presented in the order of the Mol object.

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/methanol.xyz')
mol.print_geometry()
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional
mf.kernel()

# Pre-calculation
e = mol1.nelec[0] # Number of electrons/2 for closed-shell systems
S =  mol1.intor('int1e_ovlp_sph') # Overlap matrix



# Post-calculation
E = mf.energy_tot() # Total energy
F = mf.get_fock() # Fock matrix
C = mf.mo_coeff # Coefficient matrix
MOs = mf.mo_energy # MO energies

ax = vis_mat(F,plot = False,return_ax = True,labels = False)
plt.title('$\mathbf{F}$')
offset = 0
for i in mol.atoms:
    ax.text(0.5+offset, 0.5+offset, (i),ha="center", va="center", color="white",fontsize = 14)
    if i == 'H':
        offset += 1
    if i == 'C' or i == 'O' or i == 'N':
        offset += 5
plt.show()
ax = vis_mat(S,plot = False,return_ax = True,labels = False)
plt.title('$\mathbf{S}$')
offset = 0
for i in mol.atoms:
    ax.text(0.5+offset, 0.5+offset, (i),ha="center", va="center", color="black",fontsize = 14)
    if i == 'H':
        offset += 1
    if i == 'C' or i == 'O' or i == 'N':
        offset += 5
plt.show()
# Out:
# (0), H: [-0.0154  -0.02643 -0.00336]
# (1), H: [-0.49223  0.94519  1.41443]
# (2), H: [1.06383 0.04772 1.41482]
# (3), H: [-0.65236 -1.13195  2.53683]
# (4), C: [0.00946 0.01718 1.09182]
# (5), O: [-0.66754 -1.15644  1.56374]
# converged SCF energy = -115.134078585895

# %% [markdown]
# ### Normalizing MOs
#
# After solving
#
# $$\mathbf{F} \mathbf{C}^{B} = (\mathbf{S}^{AO})^{-1} \mathbf{C}^{B} \text{diag}(\mathbf{\varepsilon})$$
#
# we can go from an __orthogonal__ to  an __orthonormal__ basis by doing
#
# $$C^B_{ji} \rightarrow \frac{C^B_{ji}}{\sqrt{S^B_{ii}}} = C^{N}_{ji},$$
#
# where
#
# $$\mathbf{S}^B = (\mathbf{C}^{B})^T \mathbf{S}^{AO} \mathbf{C}^B. $$
#
# We can easily see this by writing $\mathbf{S}^B$ explicitly as
#
# $$S_{ij}^B = \sum_{k_1} C^{B}_{k_1,i} <\psi_{k_1}^{AO}| \sum_{k_2} C^{B}_{k_2,j} |\psi_{k_2}^{AO}>$$
#
# which for the diagonal this gives
#
# $$ S_{ii}^B = \sum_{k_1}\sum_{k_2}  C^{B}_{k_1,i} C^{B}_{k_2,i} <\psi_{k_1}^{AO}|\psi_{k_2}^{AO}>. $$
#
# This results in
#
# $$ 1 = \frac{\sum_{k_1}\sum_{k_2}  C^{B}_{k_1,i} C^{B}_{k_2,i} <\psi_{k_1}^{AO}|\psi_{k_2}^{AO}>}{S^B_{ii}} = S_{ii}^{N},$$
#
# making the diagonal of $\mathbf{S}^N$ equal to $\mathbf{1}$. Note that the off-diagonal elements are not affected by this procedure since
#
# $$S^N_{ij} = \frac{S^B_{ij}}{\sqrt{S^B_{ii}S^B_{jj}}},  $$
#
# meaning they are only scaled by a constant, still yielding zero. We can easily find $\mathbf{S}^N$ by doing
#
# $$\mathbf{S}^N = (\mathbf{C}^{N})^T \mathbf{S}^{AO} \mathbf{C}^N. $$

# %% [markdown]
# ### Initializing DFT + single SCF iteration \& normalization procedure

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/methanol.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional

### Generate initial density matrix based on free-atom densities
dm_guess = mf.init_guess_by_atom()
#### Calculate corresponding Fock matrix
F_guess = mf.get_fock(dm = dm_guess)
#########
###############################################################################################
###############################################################################################
############################# DO YOUR MACHINE LEARNING CORRECTIONS HERE ##########################
###############################################################################################
###############################################################################################
#### Diagonalize this matrix
MOs_guess, C_guess = eig(np.linalg.inv(S)@ F_guess)
#### Calculate MO overlap matrix
SB = C_guess.T @ S @ C_guess
vis_mat(SB, labels = False, plot = False)
plt.title('$\mathbf{S}^B$ (orthogonal)')
plt.show()
#### normalize C matrix
for i in range(C_guess.shape[0]): 
        C_guess[:,i] /= np.sqrt(SB[i,i])
### Overlap matrix for orthonormal MOs
SN = C_guess.T @ S @ C_guess
vis_mat(SN, labels = False, plot = False)
plt.title('$\mathbf{S}^N$ (orthonormal)')
plt.show()
##### Resulting density matrix after 1 diagonalization
dm_guess2 =  2*C_guess[:,:e] @ C_guess.T[:e,:] 
##### Energy obtained from this density matrix
E1 = mf.energy_tot(dm = dm_guess2)
##### Continue using PySCF with obtained density matrix
mf.verbose = 5 # = 5 prints all the iterations, setting this to 0 suppresses this 
mf.kernel(dm0 = dm_guess2)
E = mf.energy_tot()
print('\nEnergy after 1 iteration: ' + str(E1))
print('Converged energy: ' + str(E))
# Out:
# ******** <class 'pyscf.dft.rks.RKS'> ********
# method = RKS-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/toby/master_project_scripts/Project/tmp0i7l_995
# max_memory 4000 MB (current use 338 MB)
# XC functionals = pbe
# small_rho_cutoff = 1e-07
# Set gradient conv threshold to 3.16228e-05
# cond(S) = 9.408422721870373
# nelec by numeric integration = 17.99999850335015
#     CPU time for vxc      0.55 sec, wall time      0.08 sec
# E1 = -236.72743844678965  Ecoul = 97.22258844509606  Exc = -15.537655550059466
# init E= -115.116230421209
#     CPU time for initialize scf      0.82 sec, wall time      0.12 sec
#   HOMO = -0.0150495709328529  LUMO = 0.273589031285171
#   mo_energy =
# [-1.86002945e+01 -9.96173596e+00 -8.24794398e-01 -5.83300823e-01
#  -3.79023763e-01 -3.58455868e-01 -3.17002897e-01 -1.11934108e-01
#  -1.50495709e-02  2.73589031e-01  3.45155825e-01  3.74023289e-01
#   3.93412448e-01  4.22448146e-01]
# nelec by numeric integration = 17.999998241696424
#     CPU time for vxc      0.58 sec, wall time      0.08 sec
# E1 = -235.87836684366  Ecoul = 96.29019708245971  Exc = -15.440789154293672
# cycle= 1 E= -115.10268378495  delta_E= 0.0135  |g|= 0.321  |ddm|= 0.784
#     CPU time for cycle= 1      0.76 sec, wall time      0.11 sec
#   HOMO = -0.158327379343633  LUMO = 0.2396228879731
#   mo_energy =
# [-18.92120827  -9.78000714  -0.92774097  -0.55706257  -0.40562548
#   -0.31665771  -0.31579359  -0.23076927  -0.15832738   0.23962289
#    0.31791924   0.42935202   0.43093318   0.44924617]
# nelec by numeric integration = 17.999998552755677
#     CPU time for vxc      0.73 sec, wall time      0.11 sec
# E1 = -236.91115464207874  Ecoul = 97.48263573954486  Exc = -15.577284852321654
# cycle= 2 E= -115.079528624311  delta_E= 0.0232  |g|= 0.416  |ddm|= 0.959
#     CPU time for cycle= 2      0.93 sec, wall time      0.15 sec
#   HOMO = -0.0770030329196352  LUMO = 0.258694918617849
#   mo_energy =
# [-18.73060373  -9.89663799  -0.86172996  -0.57378454  -0.38532429
#   -0.34093204  -0.31825491  -0.16907388  -0.07700303   0.25869492
#    0.34200449   0.39305416   0.40417657   0.41650556]
# nelec by numeric integration = 17.99999839426482
#     CPU time for vxc      0.59 sec, wall time      0.08 sec
# E1 = -236.41949987602345  Ecoul = 96.85758232303182  Exc = -15.498395047921406
# cycle= 3 E= -115.134037470369  delta_E= -0.0545  |g|= 0.0108  |ddm|= 0.533
#     CPU time for cycle= 3      0.90 sec, wall time      0.13 sec
#   HOMO = -0.0738716274294794  LUMO = 0.260729246205575
#   mo_energy =
# [-18.72731881  -9.88861013  -0.85937765  -0.57163751  -0.38315407
#   -0.33930042  -0.31588528  -0.16525198  -0.07387163   0.26072925
#    0.34367568   0.39495589   0.40567295   0.41893207]
# nelec by numeric integration = 17.99999839051946
#     CPU time for vxc      0.76 sec, wall time      0.11 sec
# E1 = -236.35257011726011  Ecoul = 96.78617450033568  Exc = -15.493945636110265
# cycle= 4 E= -115.134066122491  delta_E= -2.87e-05  |g|= 0.00609  |ddm|= 0.0253
#     CPU time for cycle= 4      1.01 sec, wall time      0.15 sec
#   HOMO = -0.0752125178424303  LUMO = 0.259214813550949
#   mo_energy =
# [-18.73020229  -9.89190695  -0.86085127  -0.57265003  -0.38429617
#   -0.34020445  -0.31699423  -0.16637467  -0.07521252   0.25921481
#    0.34258996   0.3939528    0.40474392   0.41788309]
# nelec by numeric integration = 17.99999839133904
#     CPU time for vxc      0.65 sec, wall time      0.09 sec
# E1 = -236.37777294706447  Ecoul = 96.81308822251603  Exc = -15.495668911106403
# cycle= 5 E= -115.134078505111  delta_E= -1.24e-05  |g|= 0.000492  |ddm|= 0.00872
#     CPU time for cycle= 5      0.80 sec, wall time      0.11 sec
#   HOMO = -0.0752368138308715  LUMO = 0.259257463210622
#   mo_energy =
# [-18.73030625  -9.89176963  -0.86082554  -0.57263192  -0.38427698
#   -0.34015265  -0.31699861  -0.16644604  -0.07523681   0.25925746
#    0.34260197   0.39400425   0.40478675   0.41785737]
# nelec by numeric integration = 17.999998391602926
#     CPU time for vxc      0.60 sec, wall time      0.09 sec
# E1 = -236.37791179754296  Ecoul = 96.81326970323305  Exc = -15.495711621508788
# cycle= 6 E= -115.134078585275  delta_E= -8.02e-08  |g|= 3.96e-05  |ddm|= 0.000727
#     CPU time for cycle= 6      0.76 sec, wall time      0.11 sec
#   HOMO = -0.0752481097966176  LUMO = 0.259250936135746
#   mo_energy =
# [-18.73032629  -9.89176828  -0.86083513  -0.57263067  -0.38428191
#   -0.34015389  -0.31699467  -0.16645754  -0.07524811   0.25925094
#    0.34259701   0.39400323   0.40478358   0.41786562]
# nelec by numeric integration = 17.99999839160505
#     CPU time for vxc      0.62 sec, wall time      0.09 sec
# E1 = -236.378006617135  Ecoul = 96.81337307971337  Exc = -15.495720179011572
# cycle= 7 E= -115.134078585889  delta_E= -6.14e-10  |g|= 4.37e-06  |ddm|= 6.77e-05
#     CPU time for cycle= 7      0.85 sec, wall time      0.12 sec
#   HOMO = -0.0752500994034279  LUMO = 0.259250161156732
#   mo_energy =
# [-18.73033048  -9.89176716  -0.86083662  -0.57263051  -0.38428252
#   -0.34015351  -0.31699527  -0.16645947  -0.0752501    0.25925016
#    0.34259641   0.3940037    0.40478379   0.41786517]
# nelec by numeric integration = 17.9999983916103
#     CPU time for vxc      0.60 sec, wall time      0.09 sec
# E1 = -236.3780286247782  Ecoul = 96.8133972504831  Exc = -15.495722342136293
# Extra cycle  E= -115.134078585887  delta_E= 1.79e-12  |g|= 5.24e-06  |ddm|= 1.43e-05
#     CPU time for scf_cycle      7.53 sec, wall time      1.11 sec
#     CPU time for SCF      7.64 sec, wall time      1.12 sec
# converged SCF energy = -115.134078585887
# nelec by numeric integration = 17.999998391610298
#     CPU time for vxc      0.50 sec, wall time      0.07 sec
# E1 = -236.3780286247782  Ecoul = 96.8133972504831  Exc = -15.49572234213629
#
# Energy after 1 iteration: -115.11623042120897
# Converged energy: -115.13407858588732

# %% [markdown]
# ### Fock matrix
#
# Can be split into density dependent part $\mathbf{B}$ and one-electron part

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/methanol.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional

### Generate initial density matrix based on free-atom densities
dm_guess = mf.init_guess_by_atom()
#### Calculate corresponding Fock matrix
B = mf.get_veff(dm = dm_guess)
h1e = mf.get_hcore()
vis_mat(B,labels = False,plot = False)
plt.title('$\mathbf{B}^{guess}$')
plt.show()
vis_mat(h1e,labels = False,plot = False)
plt.title('One-electron part')
plt.show()
vis_mat(h1e + B,labels = False,plot = False)
plt.title('Sum = $\mathbf{F}^{guess}$')
plt.show()

# %% [markdown]
# ## Only take the converged DFT matrix elements for the K-nearest neighboring atoms

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/methanol.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional
### Generate initial density matrix based on free-atom densities
dm_guess = mf.init_guess_by_atom()
#### Calculate corresponding Fock matrix
F_guess = mf.get_fock(dm = dm_guess)
mf.kernel()
F = mf.get_fock()
E = mf.energy_tot()

### change the K-nearest neighbor interactions in F_guess to F entries.
## num_H is number of basis functions for first row elements & num_O for second row
## K = 0 only adjusts diagonal blocks
F_adjusted = interaction_boundary(mol,F,F_guess, num_H = 1, num_O = 5, K = 1)

#### A little experiment
energies = []
# Pre-calculation
e = mol1.nelec[0] # Number of electrons/2 for closed-shell systems
S =  mol1.intor('int1e_ovlp_sph') # Overlap matrix
for k in range(len(mol.atoms)):
    F_adjusted = interaction_boundary(mol,F,F_guess, num_H = 1, num_O = 5, K = k)
    MOs_guess, C_guess = eig(np.linalg.inv(S)@ F_adjusted)
    #### Calculate MO overlap matrix
    SB = C_guess.T @ S @ C_guess
    #### normalize C matrix
    for i in range(C_guess.shape[0]): 
            C_guess[:,i] /= np.sqrt(SB[i,i])
    ### Overlap matrix for orthonormal MOs
    SN = C_guess.T @ S @ C_guess
    ##### Resulting density matrix after 1 diagonalization
    dm_guess2 =  2*C_guess[:,:e] @ C_guess.T[:e,:] 
    ##### Energy obtained from this density matrix
    E1 = mf.energy_tot(dm = dm_guess2)
    energies.append(E1)
energies = np.array(energies)
plt.plot(range(len(mol.atoms)),np.abs(energies-E),marker = 'o')
plt.xlabel('$K$')
plt.ylabel('$\Delta E$')
plt.yscale('log')
plt.grid(True)
plt.show()
# Out:
# converged SCF energy = -115.134078585896

# %% [markdown]
# ## Obtain machine learning data

# %%
basis = 'sto-6g'
functional = 'pbe'
mol = Mol()
mol.read_xyz('xyz_files/methanol.xyz')
mol1 = gto.M(atom=mol.pyscf_out(), basis=basis)
mf = dft.rks.RKS(mol1) 
mf.xc = functional
### Generate initial density matrix based on free-atom densities
dm_guess = mf.init_guess_by_atom()
#### Calculate corresponding Fock matrix
F_guess = mf.get_fock(dm = dm_guess)

# Obtaining maching learning data from any matrix, either F_guess, F, S etc.###
## num_H is number of basis functions for first row elements & num_O for second row
## K = 0 only takes diagonal blocks
data = extract_interaction_data(mol,F_guess,num_H = 1,num_O = 5, K = 3)
##############################################################
######################################################################




ax = vis_mat(F_guess,plot = False,return_ax = True,labels = False)
plt.title('$\mathbf{F}^{guess}$')
offset = 0
for i in mol.atoms:
    ax.text(0.5+offset, 0.5+offset, (i),ha="center", va="center", color="white",fontsize = 14)
    if i == 'H':
        offset += 1
    if i == 'C' or i == 'O' or i == 'N':
        offset += 5
plt.show()

########################################################################################################
############# First index corresponds to atom, as listed by the mol.print_geometry() function ############
############# Second index correspondst to neighbor number, i.e. 0 is self-interaction 1 ################
############# the nearest neighbor, 2 the second nearest neighbor etc.####################################
####################################################################################################
#####################################################################################################

mol.print_geometry()

## matrix elements corresponding basis functions on atom 5.
print('\nAtom 5 self-interaction:\n')
print('Matrix elements:')
print(data[5]['matrix_block'][0])
print('Distance:')
print(data[5]['distance'][0])
# rotation = r/||r|| between the two atoms
print('Rotation (= r/||r||)')
print(data[5]['rotation'][0])
print('Atomic number of the first atom and atomic number of the interacting atom')
print(data[5]['type'][0])


## matrix elements corresponding basis functions on atom 5.
print('\nInteraction of atom 4 with its nearest neighbor:\n')
print('Matrix elements:')
print(data[4]['matrix_block'][1])
print('Distance:')
print(data[4]['distance'][1])
# rotation = r/||r|| between the two atoms
print('Rotation (= r/||r||)')
print(data[4]['rotation'][1])
print('Atomic number of the first atom and atomic number of the interacting atom')
print(data[4]['type'][1])
# Out:
# /home/toby/master_project_scripts/Project/project_utilities.py:851: RuntimeWarning: invalid value encountered in true_divide
#   cache2 = [start_i, end_i,start_j, end_j,norm_dist,dist/norm_dist, atoms[i],atoms[j]]
# (0), H: [-0.0154  -0.02643 -0.00336]
# (1), H: [-0.49223  0.94519  1.41443]
# (2), H: [1.06383 0.04772 1.41482]
# (3), H: [-0.65236 -1.13195  2.53683]
# (4), C: [0.00946 0.01718 1.09182]
# (5), O: [-0.66754 -1.15644  1.56374]
#
# Atom 5 self-interaction:
#
# Matrix elements:
# [[-1.87676365e+01 -4.59326184e+00 -8.89753093e-04 -1.53653173e-03
#   -2.57355513e-03]
#  [-4.59326184e+00 -1.90609191e+00 -2.85009666e-02 -4.92887856e-02
#   -4.41937449e-02]
#  [-8.89753093e-04 -2.85009666e-02 -1.84250386e-01 -2.66693921e-02
#    9.67702837e-03]
#  [-1.53653173e-03 -4.92887856e-02 -2.66693921e-02 -2.15094279e-01
#    1.69176115e-02]
#  [-2.57355513e-03 -4.41937449e-02  9.67702837e-03  1.69176115e-02
#   -2.51600427e-01]]
# Distance:
# 0.0
# Rotation (= r/||r||)
# [nan nan nan]
# Atomic number of the first atom and atomic number of the interacting atom
# [8 8]
#
# Interaction of atom 4 with its nearest neighbor:
#
# Matrix elements:
# [[-0.66979157]
#  [-0.5262444 ]
#  [ 0.00910797]
#  [ 0.0159168 ]
#  [ 0.26657266]]
# Distance:
# 1.0963298245053814
# Rotation (= r/||r||)
# [0.02267566 0.03977818 0.99895121]
# Atomic number of the first atom and atomic number of the interacting atom
# [6 1]

# %% [markdown]
# ## Symmetry functions
#
# Information on the use of symmetry functions to describe the atomic environments can be found here: https://singroup.github.io/dscribe/latest/tutorials/acsf.html
